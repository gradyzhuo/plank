# %%
import json

# %%
with open("/Users/gradyzhuo/Downloads/downloaded-logs-20220711-183010.json", "r+") as fp:
    data = json.load(fp)

# %%
jsonPayloads = [
    datum["jsonPayload"]
    for datum in data
]

# %%
# {
#     payload["request"]["body"]["product_id"]: payload
#     for payload in jsonPayloads
# }
for payload in jsonPayloads:
    request_body = payload["request"]["body"]
    if "product_id" in request_body:
        print("product_id:", request_body["product_id"])
    else:
        # print("not found:", request_body)
# Out:
# not found: {'model': 'neridentity', 'text': '【DA測試文本】[blackbox]決戰周年慶53折起 【Biotherm 碧兒泉】男仕 活泉多水激酷保濕凝膠 100ml 超值加大版★容量升級!! ■PChome會員可累積碧兒泉會員點數 ■持續48小時大量補水 ■使肌膚澎潤有光澤 精神亦亦', 'lang': 'zh_tw'}
# not found: {'text': '【DA測試文本】[blackbox]決戰周年慶53折起 【Biotherm 碧兒泉】男仕 活泉多水激酷保濕凝膠 100ml 超值加大版★容量升級!! ■PChome會員可累積碧兒泉會員點數 ■持續48小時大量補水 ■使肌膚澎潤有光澤 精神亦亦', 'lang': 'zh_tw', 'model': 'neridentity'}
# not found: {'text': '【DA測試文本】[blackbox]決戰周年慶53折起 【Biotherm 碧兒泉】男仕 活泉多水激酷保濕凝膠 100ml 超值加大版★容量升級!! ■PChome會員可累積碧兒泉會員點數 ■持續48小時大量補水 ■使肌膚澎潤有光澤 精神亦亦', 'lang': 'zh_tw', 'model': 'neridentity'}
# not found: {'text': '【DA測試文本】[blackbox]決戰周年慶53折起 【Biotherm 碧兒泉】男仕 活泉多水激酷保濕凝膠 100ml 超值加大版★容量升級!! ■PChome會員可累積碧兒泉會員點數 ■持續48小時大量補水 ■使肌膚澎潤有光澤 精神亦亦', 'lang': 'zh_tw', 'model': 'neridentity'}
# not found: {'text': '【DA測試文本】[blackbox]決戰周年慶53折起 【Biotherm 碧兒泉】男仕 活泉多水激酷保濕凝膠 100ml 超值加大版★容量升級!! ■PChome會員可累積碧兒泉會員點數 ■持續48小時大量補水 ■使肌膚澎潤有光澤 精神亦亦', 'lang': 'zh_tw', 'model': 'neridentity'}
# ...
